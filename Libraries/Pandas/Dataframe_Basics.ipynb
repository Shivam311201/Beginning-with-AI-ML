# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivam311201/Beginning-with-AI-ML/blob/master/Libraries/Pandas/Dataframe_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/movies.csv")
df.head(3)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English

# %%
df.columns
# df.shape
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
df.industry.unique()
# Out:
# array(['Bollywood', 'Hollywood'], dtype=object)

# %%
df.language.unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
df.industry.value_counts()
# Out:
# Hollywood    20
# Bollywood    17
# Name: industry, dtype: int64

# %%
df.language.value_counts()
# Out:
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: language, dtype: int64

# %%
new_df=df[["title","imdb_rating","industry"]]
new_df
# Out:
#                                           title  imdb_rating   industry
# 0                               Pather Panchali          8.3  Bollywood
# 1   Doctor Strange in the Multiverse of Madness          7.0  Hollywood
# 2                         Thor: The Dark World           6.8  Hollywood
# 3                               Thor: Ragnarok           7.9  Hollywood
# 4                       Thor: Love and Thunder           6.8  Hollywood
# 5                      The Shawshank Redemption          9.3  Hollywood
# 6                                  Interstellar          8.6  Hollywood
# 7                      The Pursuit of Happyness          8.0  Hollywood
# 8                                     Gladiator          8.5  Hollywood
# 9                                       Titanic          7.9  Hollywood
# 10                        It's a Wonderful Life          8.6  Hollywood
# 11                                       Avatar          7.8  Hollywood
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     object
#  1   industry      37 non-null     object
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     object
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     object
#  8   currency      37 non-null     object
#  9   language      37 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.0+ KB

# %%
df[df.imdb_rating==df.imdb_rating.max()]
# Out:
#                       title   industry  release_year  imdb_rating  \
# 5  The Shawshank Redemption  Hollywood          1994          9.3
#
#                       studio  budget  revenue      unit currency language
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
df["age"]=df.release_year.apply(lambda x:2023-x)
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df["profit"]=df.apply(lambda x:x['revenue']-x['budget'],axis=1)
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
new_df=df.set_index("title")
new_df
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Thor: Ragnarok                               Hollywood          2017
# Thor: Love and Thunder                       Hollywood          2022
# The Shawshank Redemption                     Hollywood          1994
# Interstellar                                 Hollywood          2014
# The Pursuit of Happyness                     Hollywood          2006
# Gladiator                                    Hollywood          2000
# Titanic                                      Hollywood          1997
# It's a Wonderful Life                        Hollywood          1946
# Avatar                                       Hollywood          2009
# ...

# %%
new_df.index
new_df.loc['RRR']
# Out:
# industry                Bollywood
# release_year                 2022
# imdb_rating                   8.0
# studio          DVV Entertainment
# budget                        5.5
# revenue                      12.0
# unit                     Billions
# currency                      INR
# language                   Telugu
# age                             1
# profit                        6.5
# Name: RRR, dtype: object

# %%
new_df.loc[['RRR','Shershaah']]
# Out:
#             industry  release_year  imdb_rating              studio  budget  \
# title
# RRR        Bollywood          2022          8.0   DVV Entertainment     5.5
# Shershaah  Bollywood          2021          8.4  Dharma Productions   500.0
#
#            revenue      unit currency language  age  profit
# title
# RRR           12.0  Billions      INR   Telugu    1     6.5
# Shershaah    950.0  Millions      INR    Hindi    2   450.0

# %%
new_df.loc['Shershaah']
# Out:
# industry                 Bollywood
# release_year                  2021
# imdb_rating                    8.4
# studio          Dharma Productions
# budget                       500.0
# revenue                      950.0
# unit                      Millions
# currency                       INR
# language                     Hindi
# age                              2
# profit                       450.0
# Name: Shershaah, dtype: object

# %%
df.loc[0]
# Out:
# title                     Pather Panchali
# industry                        Bollywood
# release_year                         1955
# imdb_rating                           8.3
# studio          Government of West Bengal
# budget                            70000.0
# revenue                          100000.0
# unit                            Thousands
# currency                              INR
# language                          Bengali
# age                                    68
# profit                            30000.0
# Name: 0, dtype: object
