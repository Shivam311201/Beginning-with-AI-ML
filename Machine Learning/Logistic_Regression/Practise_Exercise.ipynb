# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivam311201/Beginning-with-AI-ML/blob/master/Machine%20Learning/Logistic_Regression/Practise_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('/content/sample_data/HR_comma_sep.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %% [markdown]
# # How to perform ?
#
#
# 1.   Categorical-Categorical -> Group by one category and value count on other
# 2.   Categorical-Numerical -> Group by category and mean/median on numerical

# %% [markdown]
# #### Department has no particular significance on retention

# %%
df.groupby('Department')['left'].value_counts(normalize=True)*100
# Out:
# Department   left
# IT           0       77.750611
#              1       22.249389
# RandD        0       84.625159
#              1       15.374841
# accounting   0       73.402868
#              1       26.597132
# hr           0       70.906631
#              1       29.093369
# management   0       85.555556
#              1       14.444444
# marketing    0       76.340326
#              1       23.659674
# product_mng  0       78.048780
#              1       21.951220
# sales        0       75.507246
#              1       24.492754
# support      0       75.100942
#              1       24.899058
# technical    0       74.375000
#              1       25.625000
# Name: proportion, dtype: float64

# %% [markdown]
# #### Higher satisfaction level has higher retention

# %%
df.groupby('left')['satisfaction_level'].mean()
# Out:
# left
# 0    0.666810
# 1    0.440098
# Name: satisfaction_level, dtype: float64

# %%
df.groupby('left')['satisfaction_level'].median()
# Out:
# left
# 0    0.69
# 1    0.41
# Name: satisfaction_level, dtype: float64

# %% [markdown]
# #### Last_evaluation has no particular significance on retention

# %%
df.groupby('left')['last_evaluation'].mean()
# Out:
# left
# 0    0.715473
# 1    0.718113
# Name: last_evaluation, dtype: float64

# %% [markdown]
# #### Number_project has no particular significance on retention

# %%
df.groupby('left')['number_project'].mean()
# Out:
# left
# 0    3.786664
# 1    3.855503
# Name: number_project, dtype: float64

# %% [markdown]
# #### Higher average_montly_hours has lower retention

# %%
df.groupby('left')['average_montly_hours'].mean()
# Out:
# left
# 0    199.060203
# 1    207.419210
# Name: average_montly_hours, dtype: float64

# %% [markdown]
# #### Time_spend_company has no particular significance on retention

# %%
df.groupby('left')['time_spend_company'].mean()
# Out:
# left
# 0    3.380032
# 1    3.876505
# Name: time_spend_company, dtype: float64

# %% [markdown]
# #### Promoted employees has higher retention

# %%
df.groupby('promotion_last_5years')['left'].value_counts(normalize=True)*100
# Out:
# promotion_last_5years  left
# 0                      0       75.803815
#                        1       24.196185
# 1                      0       94.043887
#                        1        5.956113
# Name: proportion, dtype: float64

# %% [markdown]
# #### High Salaried employees has higher retention

# %%
df.groupby('salary')['left'].value_counts(normalize=True)*100
# Out:
# salary  left
# high    0       93.371059
#         1        6.628941
# low     0       70.311646
#         1       29.688354
# medium  0       79.568725
#         1       20.431275
# Name: proportion, dtype: float64

# %% [markdown]
# # Remove other variables

# %%
dummies=pd.get_dummies(df['salary'],prefix='salary')
dummies
# Out:
#        salary_high  salary_low  salary_medium
# 0            False        True          False
# 1            False       False           True
# 2            False       False           True
# 3            False        True          False
# 4            False        True          False
# ...            ...         ...            ...
# 14994        False        True          False
# 14995        False        True          False
# 14996        False        True          False
# 14997        False        True          False
# 14998        False        True          False
#
# [14999 rows x 3 columns]

# %%
df=pd.concat([df,dummies],axis=1)
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.drop(['salary','salary_medium','Department','last_evaluation','number_project','Work_accident','time_spend_company'],axis=1,inplace=True)
df
# Out:
#        satisfaction_level  average_montly_hours  left  promotion_last_5years  \
# 0                    0.38                   157     1                      0
# 1                    0.80                   262     1                      0
# 2                    0.11                   272     1                      0
# 3                    0.72                   223     1                      0
# 4                    0.37                   159     1                      0
# ...                   ...                   ...   ...                    ...
# 14994                0.40                   151     1                      0
# 14995                0.37                   160     1                      0
# 14996                0.37                   143     1                      0
# 14997                0.11                   280     1                      0
# 14998                0.37                   158     1                      0
#
#        salary_high  salary_low
# ...

# %%
df.groupby('left').mean()
# Out:
#       satisfaction_level  average_montly_hours  promotion_last_5years  \
# left
# 0               0.666810            199.060203               0.026251
# 1               0.440098            207.419210               0.005321
#
#       salary_high  salary_low
# left
# 0        0.101068    0.450123
# 1        0.022963    0.608233

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary_high','salary_low']],df.left,train_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model.score(X_test,y_test)
# Out:
# 0.7821904761904762
